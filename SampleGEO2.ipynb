# %%
from bokeh.io import output_file, output_notebook, show
from bokeh.models import (
  GMapPlot, GMapOptions, ColumnDataSource, Circle, DataRange1d, PanTool, WheelZoomTool, BoxSelectTool
)

output_notebook()


map_options = GMapOptions(lat=30.29, lng=-97.73, map_type="roadmap", zoom=11)

plot = GMapPlot(
    x_range=DataRange1d(), y_range=DataRange1d(), map_options=map_options,
    api_key="AIzaSyC3MV9OORl-yimUfjSdrPfRe5GbCOCXpRU"
)
plot.title.text = "Austin"

source = ColumnDataSource(
    data=dict(
        lat=[30.29, 30.20, 30.29],
        lon=[-97.70, -97.74, -97.78],
    )
)

circle = Circle(x="lon", y="lat", size=15, fill_color="blue", fill_alpha=0.8, line_color=None)
plot.add_glyph(source, circle)

plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())
#output_file("gmap_plot.html")
show(plot)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d0a545d4-0f70-4800-bb4a-d32ec58daf00">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="9c13ab65-5f01-477b-87b1-43e1208e3e5b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9c13ab65-5f01-477b-87b1-43e1208e3e5b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9c13ab65-5f01-477b-87b1-43e1208e3e5b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"68375590-3939-472e-b05d-15694be16863":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"a399933f-4f67-414d-8dfa-410756b284f3","type":"PanTool"},{"id":"b2056a41-ce2e-470b-9eb1-22c41b1fd1e9","type":"WheelZoomTool"},{"id":"4951f7d8-d641-46f2-983d-c763eecbc1b1","type":"BoxSelectTool"}]},"id":"07143eb3-6de8-4004-8f9c-b599354ab69a","type":"Toolbar"},{"attributes":{"callback":null,"overlay":{"id":"f7321814-3413-4b27-9dda-60cea2c24441","type":"BoxAnnotation"},"plot":{"id":"2a631d8b-7bb1-4acc-bda8-7c63ee64c829","type":"GMapPlot"}},"id":"4951f7d8-d641-46f2-983d-c763eecbc1b1","type":"BoxSelectTool"},{"attributes":{"plot":{"id":"2a631d8b-7bb1-4acc-bda8-7c63ee64c829","type":"GMapPlot"}},"id":"a399933f-4f67-414d-8dfa-410756b284f3","type":"PanTool"},{"attributes":{"api_key":"AIzaSyC3MV9OORl-yimUfjSdrPfRe5GbCOCXpRU","map_options":{"lat":30.29,"lng":-97.73,"map_type":"roadmap","zoom":11},"renderers":[{"id":"9373553b-ea4c-4850-8405-7ee3987893bc","type":"GlyphRenderer"},{"id":"f7321814-3413-4b27-9dda-60cea2c24441","type":"BoxAnnotation"}],"title":{"id":"cccd5f4d-567e-452d-9385-191bdcf2c275","type":"Title"},"tool_events":{"id":"69f89205-4d5c-4727-9bc5-1e3824d29c9c","type":"ToolEvents"},"toolbar":{"id":"07143eb3-6de8-4004-8f9c-b599354ab69a","type":"Toolbar"},"x_range":{"id":"8820aeb2-3b4c-4f2d-842f-b3b17798ee3d","type":"DataRange1d"},"y_range":{"id":"c5c63ec1-9b6e-4165-8489-4f7e44227777","type":"DataRange1d"}},"id":"2a631d8b-7bb1-4acc-bda8-7c63ee64c829","type":"GMapPlot"},{"attributes":{"plot":null,"text":"Austin"},"id":"cccd5f4d-567e-452d-9385-191bdcf2c275","type":"Title"},{"attributes":{"callback":null},"id":"c5c63ec1-9b6e-4165-8489-4f7e44227777","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["lon","lat"],"data":{"lat":[30.29,30.2,30.29],"lon":[-97.7,-97.74,-97.78]}},"id":"246c95ba-55a7-4f89-abf8-8178b8c4be61","type":"ColumnDataSource"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"f7321814-3413-4b27-9dda-60cea2c24441","type":"BoxAnnotation"},{"attributes":{},"id":"69f89205-4d5c-4727-9bc5-1e3824d29c9c","type":"ToolEvents"},{"attributes":{"callback":null},"id":"8820aeb2-3b4c-4f2d-842f-b3b17798ee3d","type":"DataRange1d"},{"attributes":{"fill_alpha":{"value":0.8},"fill_color":{"value":"blue"},"line_color":{"value":null},"size":{"units":"screen","value":15},"x":{"field":"lon"},"y":{"field":"lat"}},"id":"3d20092b-a39e-4dc3-a442-45a93752e118","type":"Circle"},{"attributes":{"plot":{"id":"2a631d8b-7bb1-4acc-bda8-7c63ee64c829","type":"GMapPlot"}},"id":"b2056a41-ce2e-470b-9eb1-22c41b1fd1e9","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"246c95ba-55a7-4f89-abf8-8178b8c4be61","type":"ColumnDataSource"},"glyph":{"id":"3d20092b-a39e-4dc3-a442-45a93752e118","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"9373553b-ea4c-4850-8405-7ee3987893bc","type":"GlyphRenderer"}],"root_ids":["2a631d8b-7bb1-4acc-bda8-7c63ee64c829"]},"title":"Bokeh Application","version":"0.12.0"}};
#             var render_items = [{"docid":"68375590-3939-472e-b05d-15694be16863","elementid":"9c13ab65-5f01-477b-87b1-43e1208e3e5b","modelid":"2a631d8b-7bb1-4acc-bda8-7c63ee64c829","notebook_comms_target":"0bcc23b4-d359-49b4-a995-5785669966c6"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#         });
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#       for (var i = 0; i < inline_js.length; i++) {
#         inline_js[i](window.Bokeh);
#       }
#     }
#
#     if (window._bokeh_is_loading === 0) {
#       console.log("Bokeh: BokehJS loaded, going straight to plotting");
#       run_inline_js();
#     } else {
#       load_libs(js_urls, function() {
#         console.log("Bokeh: BokehJS plotting callback run at", now());
#         run_inline_js();
#       });
#     }
#   }(this));
# </script>
# <p><code>&lt;Bokeh Notebook handle for <strong>In[2]</strong>&gt;</code></p>
